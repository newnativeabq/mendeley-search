# %%
import pandas as pd

# %%
def searchItem(line, item):
    if item in line:
        return True
    else:
        return False

# %%
def getDocLen(filename):
    count = 0
    with open(filename, 'rb') as f:
        for line in f: count += 1
    return count

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

def joinTerm(list_to_join):
    components = list_to_join.copy()
    
    if len(components) > 0:
        new_list = [components[0]]
    else:
        return ''
    
    for component in components[1:]:
        if "'" in component and component.index("'") < 1:
            new_list.append(component.lower())                
        elif component.isalpha() or component.isnumeric():
            new_list.append(' ' + component.lower())
            
    return ''.join(new_list)


def getTerm(line):
    line_list = word_tokenize(line)
    try:
        if searchItem(line=line, item=','):
            term_end_position = min(line_list.index(','), line_list.index('('))
        else:
            term_end_position = line_list.index('(')
    except ValueError:
        return ''
    
    return joinTerm(line_list[:term_end_position])

# %%
print(joinTerm(['ada', "s", "Pies"]))
# Out:
# ada s pies

# %%
filename = 'meddict_raw.txt'
doclen = getDocLen(filename)
print(doclen)
# Out:
# 226870

# %%
# Build term list!
def buildList(filename):
    with open(filename, 'r') as f:
        terms = []
        for _ in range(doclen):
            
            line = f.readline()
            if searchItem(line=line, item='('):
                terms.append(getTerm(line))
    return terms

# %%
terms = buildList(filename)

# %%
print(terms[400:420], len(terms))
# Out:
# ['acrasia', 'acratia', 'acraturesis', 'Acree-Rosenheim test', 'acremoniosis', 'aciidine', 'acriflavine', 'acrisia', 'acritochromacy', 'acroaesthesia', 'acroanesthesia', 'acroarthritis', 'acroasphyzia', 'acroatazia', 'acrobystiolith', 'acrobystitis', 'acrocarpous', 'acrochordon', 'acrocinesia', 'acrocyanosis'] 24736

# %%
# Not bad.  24,000 terms should be a big enough sample.
# Next is calculating lexical difficulty or word complexity and getting everyting into a dataframe

df_terms = pd.DataFrame(terms, columns=['terms'])['terms'].unique()
df_terms = pd.DataFrame(df_terms, columns=['terms'])
print('Unique terms: ', df_terms.count())
df_terms.head()
# Out:
# Unique terms:  terms    21056
# dtype: int64
#            terms
# 0         Aachen
# 1          abaca
# 2        abactio
# 3  Abadie's sign
# 4    abaissement

# %%
# A robust method is proposed here: https://www.aclweb.org/anthology/D18-1410 - they had people rank 15000 words
# According to some researchers at Stanford, the length of words reflects their complexity https://langcog.stanford.edu/papers_new/lewis-2015-underrev.pdf
# We could also try to detect wheter a word is latin or greek-derived

df_terms['word_len'] = df_terms['terms'].str.len()
df_terms.sort_values(by='word_len').head()
# Out:
#       terms  word_len
# 18                  0
# 12081     m         1
# 1647      H         1
# 7258      f         1
# 17562     5         1

# %%
# We have some nonsense here.  Let's stick with 4 letters or more for now.
df_terms = df_terms[df_terms['word_len'] > 3]
df_terms.sort_values(by='word_len').head(100)
# Out:
#       terms  word_len
# 2099   balm         4
# 10911  peel         4
# 10915  pint         4
# 8545   heal         4
# 8532   Hata         4
# 10922  side         4
# 15395  tive         4
# 18857  taon         4
# 5909   ysis         4
# 10937  1000         4
# 5908   eron         4
# 10960  Bi-2         4
# 18893  teak         4
# 18894  tear         4
# 985    amyl         4
# 15278  poly         4
# 18940  room         4
# 8438   gyre         4
# 15142  gr 8         4
# 15101  gums         4
# 18993  jene         4
# 2063   only         4
# 4869   go's         4
# 8417   aner         4
# 404    ac''         4
# 11021  l.''         4
# 19027  aden         4
# 19030  icie         4
# 19036  ulum         4
# 15274  poll         4
# ...     ...       ...
# 8153   gr s         4
# 4976   lens         4
# 11337  ulus         4
# 2734   ment         4
# 11360  5-30         4
# 14519  cacy         4
# 11370  salt         4
# 8145   dram         4
# 14454  peri         4
# 11384  maim         4
# 11385  main         4
# 8124   U.S.         4
# 1118   23Â°         4
# 293    oily         4
# 5775   D.'s         4
# 19815  ihin         4
# 5771   sign         4
# 5032   yoma         4
# 1589   area         4
# 1135   root         4
# 19832  r. i         4
# 3516   31-2         4
# 11434  malt         4
# 5069   dead         4
# 2723   ^V-i         4
# 8198   gnat         4
# 10687  lead         4
# 19505  gram         4
# 5794   dyne         4
# 2074   of 3         4
#
# [100 rows x 2 columns]

# %%
# We're getting somewhere.  There are some terms that are useless, though.
# Some patterns to find and drop:
# number+anything can go
# "of number" is likely all useless
# We'll kill acronyms of the form "letter.letter"
# Anything with a special character
# "letter+letter "

# And a few more

# Diving into some regex
patterns = ('[0-9]+.',
            '[0-9]+-.',
            'of .',
            '.\..',
            'gr .',
            '\W.+',
            '\w+-',
            '\w+\W',
            '\w+-\d+',
           )
clean_d = df_terms.copy()

#conditional = clean_d.sort_values(by='word_len').head(100)['terms'].str.match(pat = patterns[0])\

for pattern in patterns:
    clean_d[pattern] = clean_d['terms'].str.match(pat=pattern)
    clean_d = clean_d[clean_d[pattern] == False]
    
clean_d.head()
# Out:
#          terms  word_len  [0-9]+.  [0-9]+-.   of .   .\..   gr .   \W.+  \
# 0       Aachen         6    False     False  False  False  False  False
# 1        abaca         5    False     False  False  False  False  False
# 2      abactio         7    False     False  False  False  False  False
# 4  abaissement        11    False     False  False  False  False  False
# 5  abalienated        11    False     False  False  False  False  False
#
#     \w+-  \w+\W  \w+-\d+
# 0  False  False    False
# 1  False  False    False
# 2  False  False    False
# 4  False  False    False
# 5  False  False    False

# %%
clean_d.sort_values(by='word_len').head(100)
# Out:
#       terms  word_len  [0-9]+.  [0-9]+-.   of .   .\..   gr .   \W.+   \w+-  \
# 12708  Tine         4    False     False  False  False  False  False  False
# 19030  icie         4    False     False  False  False  False  False  False
# 19036  ulum         4    False     False  False  False  False  False  False
# 16058  flea         4    False     False  False  False  False  False  False
# 5221   year         4    False     False  False  False  False  False  False
# 19081  aism         4    False     False  False  False  False  False  False
# 5277   derm         4    False     False  False  False  False  False  False
# 3277   caul         4    False     False  False  False  False  False  False
# 2338   tion         4    False     False  False  False  False  False  False
# 3273   ture         4    False     False  False  False  False  False  False
# 19027  aden         4    False     False  False  False  False  False  False
# 15635  face         4    False     False  False  False  False  False  False
# 8552   able         4    False     False  False  False  False  False  False
# 4385   limn         4    False     False  False  False  False  False  False
# 8547   hear         4    False     False  False  False  False  False  False
# 11272  cles         4    False     False  False  False  False  False  False
# 19273  ibre         4    False     False  False  False  False  False  False
# 19336  nbir         4    False     False  False  False  False  False  False
# 2351   bind         4    False     False  False  False  False  False  False
# 19394  soap         4    False     False  False  False  False  False  False
# 8545   heal         4    False     False  False  False  False  False  False
# 11206  lues         4    False     False  False  False  False  False  False
# 16065  pulp         4    False     False  False  False  False  False  False
# 16068  Ique         4    False     False  False  False  False  False  False
# 16070  tism         4    False     False  False  False  False  False  False
# 959    part         4    False     False  False  False  False  False  False
# 5156   elor         4    False     False  False  False  False  False  False
# 18797  spot         4    False     False  False  False  False  False  False
# 6553   also         4    False     False  False  False  False  False  False
# 18813  sure         4    False     False  False  False  False  False  False
# ...     ...       ...      ...       ...    ...    ...    ...    ...    ...
# 5447   rhea         4    False     False  False  False  False  False  False
# 1737   work         4    False     False  False  False  False  False  False
# 19815  ihin         4    False     False  False  False  False  False  False
# 8438   gyre         4    False     False  False  False  False  False  False
# 11298  lyze         4    False     False  False  False  False  False  False
# 11337  ulus         4    False     False  False  False  False  False  False
# 2371   bios         4    False     False  False  False  False  False  False
# 15395  tive         4    False     False  False  False  False  False  False
# 11370  salt         4    False     False  False  False  False  False  False
# 11384  maim         4    False     False  False  False  False  False  False
# 11385  main         4    False     False  False  False  False  False  False
# 19509  Eoid         4    False     False  False  False  False  False  False
# 15278  poly         4    False     False  False  False  False  False  False
# 19575  thos         4    False     False  False  False  False  False  False
# 15274  poll         4    False     False  False  False  False  False  False
# 15101  gums         4    False     False  False  False  False  False  False
# 1761   asci         4    False     False  False  False  False  False  False
# 4288   uria         4    False     False  False  False  False  False  False
# 2387   muth         4    False     False  False  False  False  False  False
# 11434  malt         4    False     False  False  False  False  False  False
# 15017  mals         4    False     False  False  False  False  False  False
# 14974  pine         4    False     False  False  False  False  False  False
# 1135   root         4    False     False  False  False  False  False  False
# 11455  gani         4    False     False  False  False  False  False  False
# 2411   bite         4    False     False  False  False  False  False  False
# 8532   Hata         4    False     False  False  False  False  False  False
# 11710  cord         4    False     False  False  False  False  False  False
# 4531   fios         4    False     False  False  False  False  False  False
# 3315   tomy         4    False     False  False  False  False  False  False
# 17747  icae         4    False     False  False  False  False  False  False
#
#        \w+\W  \w+-\d+
# 12708  False    False
# 19030  False    False
# 19036  False    False
# 16058  False    False
# 5221   False    False
# 19081  False    False
# 5277   False    False
# 3277   False    False
# 2338   False    False
# 3273   False    False
# 19027  False    False
# 15635  False    False
# 8552   False    False
# 4385   False    False
# 8547   False    False
# 11272  False    False
# 19273  False    False
# 19336  False    False
# 2351   False    False
# 19394  False    False
# 8545   False    False
# 11206  False    False
# 16065  False    False
# 16068  False    False
# 16070  False    False
# 959    False    False
# 5156   False    False
# 18797  False    False
# 6553   False    False
# 18813  False    False
# ...      ...      ...
# 5447   False    False
# 1737   False    False
# 19815  False    False
# 8438   False    False
# 11298  False    False
# 11337  False    False
# 2371   False    False
# 15395  False    False
# 11370  False    False
# 11384  False    False
# 11385  False    False
# 19509  False    False
# 15278  False    False
# 19575  False    False
# 15274  False    False
# 15101  False    False
# 1761   False    False
# 4288   False    False
# 2387   False    False
# 11434  False    False
# 15017  False    False
# 14974  False    False
# 1135   False    False
# 11455  False    False
# 2411   False    False
# 8532   False    False
# 11710  False    False
# 4531   False    False
# 3315   False    False
# 17747  False    False
#
# [100 rows x 11 columns]

# %%
# Looks a lot better.  Let's ditch the regex columns and save the dictionary out to file.
clean_d = clean_d[['terms', 'word_len']]
clean_d.to_csv('meddict_clean.csv', header=True, index=None)
